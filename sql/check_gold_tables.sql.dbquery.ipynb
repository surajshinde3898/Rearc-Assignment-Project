-- %%
-- Question 1
SELECT *
FROM adb_rearc_assignment_workspace.gold.gold_q1_population_stats_2013_2018;


-- Question 2
SELECT *
FROM adb_rearc_assignment_workspace.gold.gold_q2_bls_best_year_by_series
ORDER BY series_id;

-- Question 3
SELECT *
FROM adb_rearc_assignment_workspace.gold.gold_q3_bls_q01_with_population
ORDER BY year;
