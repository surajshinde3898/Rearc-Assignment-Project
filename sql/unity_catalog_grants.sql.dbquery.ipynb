-- %%
GRANT USE CATALOG
ON CATALOG adb_rearc_assignment_workspace
TO `rearc_gold_analysts`;

GRANT USE SCHEMA
ON SCHEMA adb_rearc_assignment_workspace.gold
TO `rearc_gold_analysts`;

GRANT SELECT
ON SCHEMA adb_rearc_assignment_workspace.gold
TO `rearc_gold_analysts`;


SHOW GRANTS `rearc_gold_analysts`
ON CATALOG adb_rearc_assignment_workspace;

SHOW GRANTS `rearc_gold_analysts`
ON SCHEMA adb_rearc_assignment_workspace.gold;
